# %%
import pymysql
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dbeaver_connect import create_df_pymysql

# %%
# Define connection details in a format that is expected by dbeaver_connect functions:

connection_details = {"host": 'eufmd-database-1.cqodkl4vazie.eu-north-1.rds.amazonaws.com',
                      "user": 'root',
                      "password": 'YOUR_PASSWORD',
                      "db": 'db_tompilot',
                      "port": 3306
}

# %%
# Define the SQL query that is expected by the dbeaver_connect functions:

df_query_dict = {"competencies": "SELECT * FROM db_tompilot.competencies",
                 "countries": "SELECT * FROM db_tompilot.countries",
                 "course_categories": "SELECT * FROM db_tompilot.course_categories",
                 "courses": "SELECT * FROM db_tompilot.courses",
                 "position_competency_by_country": "SELECT * FROM db_tompilot.position_competency_by_country",
                 "positions": "SELECT * FROM db_tompilot.positions",
                 "regions_geolocation": "SELECT * FROM db_tompilot.regions_geolocation",
                 "roles": "SELECT * FROM db_tompilot.roles",
                 "self_assessment": "SELECT * FROM db_tompilot.self_assessment",
                 "tom_enrolments": "SELECT * FROM db_tompilot.tom_enrolments",
                 "trainings": "SELECT * FROM db_tompilot.trainings",
                 "user_course_enrolled": "SELECT * FROM db_tompilot.user_course_enrolled",
                 "user_course_enrolled_moodle": "SELECT * FROM db_tompilot.user_course_enrolled_moodle",
                 "users": "SELECT * FROM db_tompilot.users",  
}

# %%
# Convert SQL queries to dataframes:

for item in df_query_dict:
    query = df_query_dict[item]
    df_query_dict[item] = create_df_pymysql(connection_details, query)
# Out:
# /Users/meganguidry/Documents/TOM-Recommender-System/dbeaver_connect.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
for item in df_query_dict:
    print(item, df_query_dict[item].shape)
# Out:
# competencies (13, 2)
# countries (12, 8)
# course_categories (34, 3)
# courses (428, 8)
# position_competency_by_country (179, 5)
# positions (23, 4)
# regions_geolocation (129, 7)
# roles (3, 3)
# self_assessment (107, 4)
# tom_enrolments (1988, 18)
# trainings (142, 12)
# user_course_enrolled (700, 7)
# user_course_enrolled_moodle (234, 10)
# users (223, 15)

# %%
# what data do we have in tom_enrolments?
tom_enrolments_df = df_query_dict["tom_enrolments"]

tom_enrolments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1988 entries, 0 to 1987
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1988 non-null   int64
#  1   full_name         1988 non-null   object
#  2   email             1988 non-null   object
#  3   course_fullname   1988 non-null   object
#  4   course_shortname  1988 non-null   object
#  5   course_category   1988 non-null   object
#  6   city              1988 non-null   object
#  7   country           1988 non-null   object
#  8   institution       1988 non-null   object
#  9   role              1988 non-null   object
#  10  completed         1988 non-null   object
#  11  time_enrolled     1988 non-null   object
#  12  time_completed    1904 non-null   object
#  13  progress          1988 non-null   float64
#  14  status            1988 non-null   object
#  15  course_id         1919 non-null   float64
#  16  moodle_category   1988 non-null   object
#  17  new_id            1988 non-null   int64
# dtypes: float64(2), int64(2), object(14)
# memory usage: 279.7+ KB

# %% [markdown]
# ## Initial questions about tom_enrolments
# #### What data is missing or incomplete?
#     - 69 values of course_id are Nan
#     - 1010 "roles" are missing. These show up in the database as blank strings ('').
#     - City, institution, and moodle_category also have many instances of blank strings.
# #### What data do we want from the tom_enrolment table?
#     - id
#     - full name
#     - course_fullname
#     - course_shortname
#     - course_category
#     - course_id
#     - country
#     - role
#     - progress (if 100 then we know it is complete)
#     - time_enrolled
#     - time_completed
# #### What is the distribution of comple vs. incomplete courses?
#     - 1365 are 50% complete
#     - 572 are fully complete
#     - 35 have not yet been progressed
#     - 8 are somewhere between not started and 50% complete
#     - 8 are somewhere between 50% complete and 100% complete
# #### What do enrolments over time look like? Are enrolments stable, increasing, decreasing, or showing other trends?
# #### Where are the learners from? (country)
# #### How long does it take for learners to complete courses?
# #### What are the most popular courses?
#
# ## Initial questions about the competencies mapping (brick skills present in each course)
# #### Why are there only 19 courses in the mapping sheet?

# %% [markdown]
# ### What data is missing or incomplete?
# At a glance it looks like there are not many missing values in the dataframe. However, the Nan values have been replaced with empty strings. I want to see how many instances of "" can be found in the tom_enrolments dataframe.

# %%
# The isna() methos shows us that there are not many Nan values in the dataframe aside from in the course_id column.
# (A Nan value in the time completed column means the course has not been completed)

tom_enrolments_df.isna().sum()
# Out:
# id                   0
# full_name            0
# email                0
# course_fullname      0
# course_shortname     0
# course_category      0
# city                 0
# country              0
# institution          0
# role                 0
# completed            0
# time_enrolled        0
# time_completed      84
# progress             0
# status               0
# course_id           69
# moodle_category      0
# new_id               0
# dtype: int64

# %%
tom_enrolments_df.head(20)
# Out:
#       id          full_name                         email  \
# 0   6379       Jon Simonyan              jsimmk19@mail.ru
# 1   6392  Mariam Militosyan         militosyan_96@mail.ru
# 2   6393  Mariam Militosyan         militosyan_96@mail.ru
# 3   6394     Irma Artushyan      irma.artushyan95@mail.ru
# 4   6395     Irma Artushyan      irma.artushyan95@mail.ru
# 5   6441         Ilhan Genc  ilhan.genc@tarimorman.gov.tr
# 6   6442         Ilhan Genc  ilhan.genc@tarimorman.gov.tr
# 7   6459      Pascal Truong      pascal.truong@bluewin.ch
# 8   6460      Pascal Truong      pascal.truong@bluewin.ch
# 9   6462         Jürg Frigg         j.frigg@laclinique.ch
# 10  6465       Brian Friker        brian.friker@gmail.com
# 11  6466       Brian Friker        brian.friker@gmail.com
# 12  6472   Claudio Paganini    Claudio.Paganini@alt.gr.ch
# 13  6476        Meret Isler             meret.isler@tg.ch
# 14  6477        Meret Isler             meret.isler@tg.ch
# 15  6478        Meret Isler             meret.isler@tg.ch
# 16  6494       Gary Delalay     gary.delalay@blv.admin.ch
# 17  6495       Simone Maier            simone.maier@ag.ch
# 18  6496       Simone Maier            simone.maier@ag.ch
# 19  6500  Jonathan Fleurent       jonathan.fleurent@vd.ch
#
#                                       course_fullname  \
# 0                            Open Session Online 2014
# 1   Обучающий Онлайн Курс по Изучению Ящура на рус...
# 2                                      Knowledge Bank
# 3   Обучающий Онлайн Курс по Изучению Ящура на рус...
# 4                            Open Session Online 2014
# 5   Altıncı Türkçe Çevrimiçi Şap Hastalığı Araştır...
# 6                                      Knowledge Bank
# 7             FMD Emergency Preparation Course (EN13)
# 8                                      Knowledge Bank
# 9             FMD Emergency Preparation Course (EN13)
# 10            FMD Emergency Preparation Course (EN13)
# 11                                     Knowledge Bank
# 12                                     Knowledge Bank
# 13            FMD Emergency Preparation Course (EN12)
# 14                                     Knowledge Bank
# 15    FMD Emergency Preparation Course - Multicountry
# 16  Organizing Simulation Exercises for Animal Dis...
# 17  African Swine Fever Preparedness Course for Eu...
# 18                                     Knowledge Bank
# 19  African Swine Fever Preparedness Course for Eu...
#
#             course_shortname                    course_category      city  \
# 0   Open Session Online 2014                                 NU    Erevan
# 1                   FITC_RU4  FMD Investigation Training Course
# 2             Knowledge Bank                                 NU
# 3                   FITC_RU4  FMD Investigation Training Course
# 4   Open Session Online 2014                                 NU
# 5                   FITC_TR6  FMD Investigation Training Course   ERZURUM
# 6             Knowledge Bank                                 NU   ERZURUM
# 7                  FEPC_EN13   FMD Emergency Preparation Course
# 8             Knowledge Bank                                 NU
# 9                  FEPC_EN13   FMD Emergency Preparation Course  Madiswil
# 10                 FEPC_EN13   FMD Emergency Preparation Course
# 11            Knowledge Bank                                 NU
# 12            Knowledge Bank                                 NU      Chur
# 13                 FEPC_EN12   FMD Emergency Preparation Course      Roma
# 14            Knowledge Bank                                 NU      Roma
# 15                   FEPC_MC   FMD Emergency Preparation Course      Roma
# 16           Simex_Workshop1               Simulation Exercises
# 17                ASF_Europe                African Swine Fever     Aarau
# 18            Knowledge Bank                                 NU     Aarau
# 19                ASF_Europe                African Swine Fever  Lausanne
#
#         country institution                                   role completed  \
# 0       Armenia                                                           No
# 1       Armenia                                                          Yes
# 2       Armenia                                                           No
# 3       Armenia                                                          Yes
# 4       Armenia                                                           No
# 5       Armenia              Central level government veterinarian       Yes
# 6       Armenia              Central level government veterinarian        No
# 7   Switzerland                  Regional level/field veterinarian       Yes
# 8   Switzerland                  Regional level/field veterinarian        No
# 9   Switzerland              Central level government veterinarian       Yes
# 10  Switzerland              Central level government veterinarian       Yes
# 11  Switzerland              Central level government veterinarian        No
# 12  Switzerland              Central level government veterinarian        No
# 13  Switzerland                                                          Yes
# 14  Switzerland                                                           No
# 15  Switzerland                                                           No
# 16  Switzerland                                           Students        No
# 17  Switzerland                                                          Yes
# 18  Switzerland                                                           No
# 19  Switzerland                                                          Yes
#
#           time_enrolled       time_completed  progress     status  course_id  \
# 0   2020-07-10 00:00:00                 None      50.0       Open       45.0
# 1   2020-09-17 00:00:00  2020-10-21 00:00:00     100.0  Completed      244.0
# 2   2020-09-28 00:00:00                 None      50.0       Open        3.0
# 3   2020-09-17 00:00:00  2020-10-21 00:00:00     100.0  Completed      244.0
# 4   2020-05-10 00:00:00                 None      50.0       Open       45.0
# 5   2022-11-14 00:00:00  2022-12-13 00:00:00     100.0  Completed      375.0
# 6   2022-11-25 00:00:00                 None      50.0       Open        3.0
# 7   2022-11-22 00:00:00  2022-12-26 00:00:00     100.0  Completed      374.0
# 8   2022-11-22 00:00:00                 None      50.0       Open        3.0
# 9   2022-11-22 00:00:00  2022-12-22 00:00:00     100.0  Completed      374.0
# 10  2022-11-22 00:00:00  2022-12-18 00:00:00     100.0  Completed      374.0
# 11  2022-11-23 00:00:00                 None      50.0       Open        3.0
# 12  2022-11-29 00:00:00                 None      50.0       Open        3.0
# 13  2022-02-22 00:00:00  2022-03-15 00:00:00     100.0  Completed      351.0
# 14  2022-07-03 00:00:00                 None      50.0       Open        3.0
# 15  2022-04-29 00:00:00                 None      50.0       Open      347.0
# 16  2022-04-20 00:00:00                 None      50.0       Open      357.0
# 17  2020-04-22 00:00:00  2020-05-25 00:00:00     100.0  Completed      230.0
# 18  2020-04-23 00:00:00                 None      50.0       Open        3.0
# 19  2020-04-22 00:00:00  2020-05-25 00:00:00     100.0  Completed      230.0
#
#                                moodle_category  new_id
# 0                     Resources / Open Session     179
# 1            FMD Investigation Training Course     180
# 2                                    Resources     181
# 3            FMD Investigation Training Course     183
# 4                     Resources / Open Session     185
# 5            FMD Investigation Training Course     186
# 6                                    Resources     189
# 7   FMD Emergency Preparation Course / English     190
# 8                                    Resources     191
# 9   FMD Emergency Preparation Course / English     192
# 10  FMD Emergency Preparation Course / English     197
# 11                                   Resources     199
# 12                                   Resources     203
# 13  FMD Emergency Preparation Course / English     204
# 14                                   Resources     205
# 15  FMD Emergency Preparation Course / English     207
# 16                        Simulation Exercises     214
# 17                         African Swine Fever     216
# 18                                   Resources     217
# 19                         African Swine Fever     219

# %%
# How many blank strings do we have in the database?

tom_enrolments_df.eq('').sum()
# Out:
# id                     0
# full_name              0
# email                  0
# course_fullname        0
# course_shortname       0
# course_category        0
# city                1004
# country                0
# institution         1756
# role                1010
# completed              0
# time_enrolled          0
# time_completed         0
# progress               0
# status                 0
# course_id              0
# moodle_category      381
# new_id                 0
# dtype: int64

# %%
tom_enrolments_df["role"].value_counts()
# Out:
# role
#                                          1010
# Regional level/field veterinarian         414
# Central level government veterinarian     396
# Laboratory staff                          104
# Other (please specify)                     44
# Students                                   17
# Private veterinarian                        3
# Name: count, dtype: int64

# %%
tom_enrolments_df["progress"].value_counts()
# Out:
# progress
# 50.0     1365
# 100.0     572
# 0.0        35
# 14.3        2
# 60.0        1
# 80.0        1
# 10.0        1
# 23.1        1
# 87.0        1
# 1.2         1
# 92.9        1
# 57.1        1
# 7.1         1
# 46.2        1
# 42.9        1
# 2.0         1
# 77.8        1
# 90.0        1
# Name: count, dtype: int64

# %%
brick_mapping_df = pd.read_excel("data/get_prepared_competencies_mapping.xlsx", skiprows=1)

# %%
brick_mapping_df.head()
# Out:
#                                            Course         Level     Acccess  \
# 0          Introduction to Foot-and-Mouth disease         Basic       Open
# 1              Introduction to Lumpy Skin disease         Basic       Open
# 2       Introduction to Biorisk Minimum Standards         Basic       Open
# 3            Introduction to Simulation Exercises         Basic       Open
# 4  FMD/RVF/SPGP/LSD Emergency preparedness course  Intermediate  Nomination
#
#                                      Disease covered Simulation exercises  \
# 0                                                FMD                  NaN
# 1                                                LSD                  NaN
# 2                                                FMD                  NaN
# 3                                               FAST                    X
# 4  Courses dedicated to one single disease among:...                  NaN
#
#    Training Laboratories Contingency planning Surveillance Awareness  ...  \
# 0       NaN          NaN                  NaN          NaN         X  ...
# 1       NaN          NaN                  NaN          NaN         X  ...
# 2       NaN            X                  NaN          NaN       NaN  ...
# 3       NaN          NaN                  NaN          NaN       NaN  ...
# 4       NaN          NaN                    X            X         X  ...
#
#   Communication Disposal Humane killing of animals Vaccination  \
# 0           NaN      NaN                       NaN         NaN
# 1           NaN      NaN                       NaN         NaN
# 2           NaN      NaN                       NaN         NaN
# 3           NaN      NaN                       NaN         NaN
# 4           NaN      NaN                       NaN         NaN
#
#   Cleaning and disinfection Control zones Wildlife Recovery of disease status  \
# 0                       NaN           NaN      NaN                        NaN
# 1                       NaN           NaN      NaN                        NaN
# 2                       NaN           NaN      NaN                        NaN
# 3                       NaN           NaN      NaN                        NaN
# 4                       NaN             X      NaN                        NaN
#
#   Vaccination exit strategy Re-stocking
# 0                       NaN         NaN
# 1                       NaN         NaN
# 2                       NaN         NaN
# 3                       NaN         NaN
# 4                       NaN         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# TODO: Create a function that loops through the courses listed in the mapping file and creates a list of all the "brick" skills that are covered in the course as well as a list of diseases covered in the course. NOTE, if a course covers FAST diseases, this means that ALL diseases of interest are covered. FAST stands for "Foot and mouth and similar transboundary animal diseases"

# %%
# Within the brick_mapping dataframe convert NaN values to 0 and X to 1

brick_mapping_df.replace(to_replace='X', value=1, inplace=True)
brick_mapping_df["Disease covered"].fillna(value='', inplace=True)
brick_mapping_df.fillna(value=0, inplace=True)

# %%
brick_mapping_df.shape
# Out:
# (19, 25)

# %%
# Convert the brick mapping dataframe into a dict for easier handling:
temp_dict = brick_mapping_df.to_dict(orient='records')

# %%
temp_dict
# Out:
# [{'Course': 'Introduction to Foot-and-Mouth disease',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Introduction to Lumpy Skin disease',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'LSD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Introduction to Biorisk Minimum Standards',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Introduction to Simulation Exercises',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'FMD/RVF/SPGP/LSD Emergency preparedness course',
#   'Level': 'Intermediate',
#   'Acccess': 'Nomination',
#   'Disease covered': 'Courses dedicated to one single disease among: FMD, RVF, SPGP and LSD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 1.0,
#   'Epidemiological Investigation': 1.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 1.0,
#   'Personal biosecurity': 1.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 1.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'FMD investigation training course (for endemic countries)\xa0\xa0',
#   'Level': 'Intermediate',
#   'Acccess': 'Nomination',
#   'Disease covered': 'Courses dedicated to one single disease among: FMD, RVF, SPGP and LSD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 1.0,
#   'Epidemiological Investigation': 1.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 1.0,
#   'Personal biosecurity': 1.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 1.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Passive surveillance. Online (multicountry) (English)',
#   'Level': 'Intermediate',
#   'Acccess': 'Nomination',
#   'Disease covered': '',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Real-Time Training',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Support to\xa0\xa0 national simulation exercises. (Face-to-face drill or tabletop)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Support to\xa0 multi-country simulation exercises',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Organizing Simulation Exercises for FAST disease emergencies  - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'FAST disease crisis management: Dealing with the psychological aspects and the public perceptions  - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 1.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Putting vaccination into practice - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 1.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 1.0,
#   'Vaccination exit strategy': 1.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Wildlife surveillance - Wworkshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 1.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 1.0,
#   'Personal biosecurity': 1.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 1.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Depopulation, disposal and cleaning and disinfection – from theory to practice - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 1.0,
#   'Humane killing of animals': 1.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 1.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Passive surveillance - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'FMD Laboratory Training (English) ',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'Capripox Laboratory Training (English) ',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'LSD/SGP',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0},
#  {'Course': 'RVF laboratory training (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'RVF',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0}]

# %%
brick_mapping_dict = {}

for dict_item in temp_dict:
    brick_mapping_dict[dict_item["Course"]] = dict_item

# %%
brick_mapping_dict['Introduction to Biorisk Minimum Standards']
# Out:
# {'Course': 'Introduction to Biorisk Minimum Standards',
#  'Level': 'Basic',
#  'Acccess': 'Open ',
#  'Disease covered': 'FMD',
#  'Simulation exercises': 0.0,
#  'Training': 0.0,
#  'Laboratories': 1.0,
#  'Contingency planning': 0.0,
#  'Surveillance': 0.0,
#  'Awareness': 0.0,
#  'Clinical Examination': 0.0,
#  'Epidemiological Investigation': 0.0,
#  'Sampling': 0.0,
#  'Farm biosecurity': 0.0,
#  'Personal biosecurity': 0.0,
#  'Communication': 0.0,
#  'Disposal': 0.0,
#  'Humane killing of animals': 0.0,
#  'Vaccination': 0.0,
#  'Cleaning and disinfection': 0.0,
#  'Control zones': 0.0,
#  'Wildlife': 0.0,
#  'Recovery of disease status': 0.0,
#  'Vaccination exit strategy': 0.0,
#  'Re-stocking': 0.0}

# %%
i = brick_mapping_dict['Introduction to Biorisk Minimum Standards']
skills_covered_in_course = []

for item in i:
    if i[item] == 1:
        skills_covered_in_course.append(item)

i["skills_covered_in_course"] = skills_covered_in_course

# %%
skills_covered_in_course
# Out:
# ['Laboratories']

# %%
brick_mapping_dict['Introduction to Biorisk Minimum Standards']
# Out:
# {'Course': 'Introduction to Biorisk Minimum Standards',
#  'Level': 'Basic',
#  'Acccess': 'Open ',
#  'Disease covered': 'FMD',
#  'Simulation exercises': 0.0,
#  'Training': 0.0,
#  'Laboratories': 1.0,
#  'Contingency planning': 0.0,
#  'Surveillance': 0.0,
#  'Awareness': 0.0,
#  'Clinical Examination': 0.0,
#  'Epidemiological Investigation': 0.0,
#  'Sampling': 0.0,
#  'Farm biosecurity': 0.0,
#  'Personal biosecurity': 0.0,
#  'Communication': 0.0,
#  'Disposal': 0.0,
#  'Humane killing of animals': 0.0,
#  'Vaccination': 0.0,
#  'Cleaning and disinfection': 0.0,
#  'Control zones': 0.0,
#  'Wildlife': 0.0,
#  'Recovery of disease status': 0.0,
#  'Vaccination exit strategy': 0.0,
#  'Re-stocking': 0.0,
#  'skills_covered_in_course': ['Laboratories']}

# %%
def add_skills_covered_to_dict(i):
    skills_covered_in_course = []
    
    for key_value in i:
        if i[key_value] == 1:
            skills_covered_in_course.append(key_value)

    i["skills_covered_in_course"] = skills_covered_in_course

# %%
brick_mapping_dict['Introduction to Lumpy Skin disease']['Awareness']
# Out:
# 1.0

# %%
add_skills_covered_to_dict(brick_mapping_dict['Introduction to Lumpy Skin disease'])

# %%
brick_mapping_dict['Introduction to Lumpy Skin disease']
# Out:
# {'Course': 'Introduction to Lumpy Skin disease',
#  'Level': 'Basic',
#  'Acccess': 'Open ',
#  'Disease covered': 'LSD',
#  'Simulation exercises': 0.0,
#  'Training': 0.0,
#  'Laboratories': 0.0,
#  'Contingency planning': 0.0,
#  'Surveillance': 0.0,
#  'Awareness': 1.0,
#  'Clinical Examination': 0.0,
#  'Epidemiological Investigation': 0.0,
#  'Sampling': 0.0,
#  'Farm biosecurity': 0.0,
#  'Personal biosecurity': 0.0,
#  'Communication': 0.0,
#  'Disposal': 0.0,
#  'Humane killing of animals': 0.0,
#  'Vaccination': 0.0,
#  'Cleaning and disinfection': 0.0,
#  'Control zones': 0.0,
#  'Wildlife': 0.0,
#  'Recovery of disease status': 0.0,
#  'Vaccination exit strategy': 0.0,
#  'Re-stocking': 0.0,
#  'skills_covered_in_course': ['Awareness']}

# %%
for i in brick_mapping_dict:
    add_skills_covered_to_dict(brick_mapping_dict[i])

# %%
brick_mapping_dict
# Out:
# {'Introduction to Foot-and-Mouth disease': {'Course': 'Introduction to Foot-and-Mouth disease',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Awareness']},
#  'Introduction to Lumpy Skin disease': {'Course': 'Introduction to Lumpy Skin disease',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'LSD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Awareness']},
#  'Introduction to Biorisk Minimum Standards': {'Course': 'Introduction to Biorisk Minimum Standards',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Laboratories']},
#  'Introduction to Simulation Exercises': {'Course': 'Introduction to Simulation Exercises',
#   'Level': 'Basic',
#   'Acccess': 'Open ',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Simulation exercises']},
#  'FMD/RVF/SPGP/LSD Emergency preparedness course': {'Course': 'FMD/RVF/SPGP/LSD Emergency preparedness course',
#   'Level': 'Intermediate',
#   'Acccess': 'Nomination',
#   'Disease covered': 'Courses dedicated to one single disease among: FMD, RVF, SPGP and LSD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 1.0,
#   'Epidemiological Investigation': 1.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 1.0,
#   'Personal biosecurity': 1.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 1.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Contingency planning',
#    'Surveillance',
#    'Awareness',
#    'Clinical Examination',
#    'Epidemiological Investigation',
#    'Sampling',
#    'Farm biosecurity',
#    'Personal biosecurity',
#    'Control zones']},
#  'FMD investigation training course (for endemic countries)\xa0\xa0': {'Course': 'FMD investigation training course (for endemic countries)\xa0\xa0',
#   'Level': 'Intermediate',
#   'Acccess': 'Nomination',
#   'Disease covered': 'Courses dedicated to one single disease among: FMD, RVF, SPGP and LSD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 1.0,
#   'Epidemiological Investigation': 1.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 1.0,
#   'Personal biosecurity': 1.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 1.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Contingency planning',
#    'Surveillance',
#    'Awareness',
#    'Clinical Examination',
#    'Epidemiological Investigation',
#    'Sampling',
#    'Farm biosecurity',
#    'Personal biosecurity',
#    'Control zones']},
#  'Passive surveillance. Online (multicountry) (English)': {'Course': 'Passive surveillance. Online (multicountry) (English)',
#   'Level': 'Intermediate',
#   'Acccess': 'Nomination',
#   'Disease covered': '',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Contingency planning',
#    'Surveillance',
#    'Awareness',
#    'Sampling']},
#  'Real-Time Training': {'Course': 'Real-Time Training',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': []},
#  'Support to\xa0\xa0 national simulation exercises. (Face-to-face drill or tabletop)': {'Course': 'Support to\xa0\xa0 national simulation exercises. (Face-to-face drill or tabletop)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Simulation exercises']},
#  'Support to\xa0 multi-country simulation exercises': {'Course': 'Support to\xa0 multi-country simulation exercises',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Simulation exercises']},
#  'Organizing Simulation Exercises for FAST disease emergencies  - Workshop (multicountry) (English)': {'Course': 'Organizing Simulation Exercises for FAST disease emergencies  - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 1.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Simulation exercises']},
#  'FAST disease crisis management: Dealing with the psychological aspects and the public perceptions  - Workshop (multicountry) (English)': {'Course': 'FAST disease crisis management: Dealing with the psychological aspects and the public perceptions  - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 1.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Communication']},
#  'Putting vaccination into practice - Workshop (multicountry) (English)': {'Course': 'Putting vaccination into practice - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 1.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 1.0,
#   'Vaccination exit strategy': 1.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Vaccination',
#    'Recovery of disease status',
#    'Vaccination exit strategy']},
#  'Wildlife surveillance - Wworkshop (multicountry) (English)': {'Course': 'Wildlife surveillance - Wworkshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 1.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 1.0,
#   'Personal biosecurity': 1.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 1.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Surveillance',
#    'Sampling',
#    'Farm biosecurity',
#    'Personal biosecurity',
#    'Wildlife']},
#  'Depopulation, disposal and cleaning and disinfection – from theory to practice - Workshop (multicountry) (English)': {'Course': 'Depopulation, disposal and cleaning and disinfection – from theory to practice - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 1.0,
#   'Humane killing of animals': 1.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 1.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Disposal',
#    'Humane killing of animals',
#    'Cleaning and disinfection']},
#  'Passive surveillance - Workshop (multicountry) (English)': {'Course': 'Passive surveillance - Workshop (multicountry) (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FAST',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 0.0,
#   'Contingency planning': 1.0,
#   'Surveillance': 1.0,
#   'Awareness': 1.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 1.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Contingency planning',
#    'Surveillance',
#    'Awareness',
#    'Sampling']},
#  'FMD Laboratory Training (English) ': {'Course': 'FMD Laboratory Training (English) ',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'FMD',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Laboratories']},
#  'Capripox Laboratory Training (English) ': {'Course': 'Capripox Laboratory Training (English) ',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'LSD/SGP',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Laboratories']},
#  'RVF laboratory training (English)': {'Course': 'RVF laboratory training (English)',
#   'Level': 'Advanced',
#   'Acccess': 'Nomination',
#   'Disease covered': 'RVF',
#   'Simulation exercises': 0.0,
#   'Training': 0.0,
#   'Laboratories': 1.0,
#   'Contingency planning': 0.0,
#   'Surveillance': 0.0,
#   'Awareness': 0.0,
#   'Clinical Examination': 0.0,
#   'Epidemiological Investigation': 0.0,
#   'Sampling': 0.0,
#   'Farm biosecurity': 0.0,
#   'Personal biosecurity': 0.0,
#   'Communication': 0.0,
#   'Disposal': 0.0,
#   'Humane killing of animals': 0.0,
#   'Vaccination': 0.0,
#   'Cleaning and disinfection': 0.0,
#   'Control zones': 0.0,
#   'Wildlife': 0.0,
#   'Recovery of disease status': 0.0,
#   'Vaccination exit strategy': 0.0,
#   'Re-stocking': 0.0,
#   'skills_covered_in_course': ['Laboratories']}}
